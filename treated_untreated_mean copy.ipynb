# %%
import os
import glob
import geopandas as gpd
import rasterio
import rasterstats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# "C:\Users\bsf31\Documents\data\NL050\30m LUCAS LULC\30m LUCAS LULC"

# %%
# Define paths
base_dir = "C:/Users/bsf31/Documents/data/NL050/30m LUCAS LULC"
Untreated_dir = r"C:\Users\bsf31\Documents\data\NL050\30m LUCAS LULC\30m LUCAS LULC\Untreated"
treated_cond_prob_dir = r"C:\Users\bsf31\Documents\data\NL050\30m LUCAS LULC\30m LUCAS LULC\Treated"

# %%
# Vector layers
vector_path = "C:/Users/bsf31/Documents/data/NL050/disaster_resilience.gpkg"
vector_layers = [
    "sb_frontcountry_existing_trts_calmapper_epsg6350",
    "g3_northsbco_vmp_rxfire_epsg6350",
    "g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350",
    "g1_lompoc_rxfire_epsg6350"
]

# %%
def process_rasters(base_path, treatment_type):
    results = []
    for date_folder in sorted(os.listdir(base_path)):
        date_path = os.path.join(base_path, date_folder)
        if not os.path.isdir(date_path):
            continue
        
        for iter_folder in sorted(os.listdir(date_path)):
            iter_path = os.path.join(date_path, iter_folder)
            if not os.path.isdir(iter_path):
                continue
            
            predict_path = os.path.join(iter_path, "Predict_LMH.tif")
            probhigh_path = os.path.join(iter_path, "ProbHigh.tif")
            
            if os.path.exists(predict_path) and os.path.exists(probhigh_path):
                for layer in vector_layers:
                    gdf = gpd.read_file(vector_path, layer=layer)
                    gdf = gdf.to_crs(epsg=3488)
                    
                    # Compute mean values
                    mean_predict = np.mean([
                        stat['mean'] for stat in rasterstats.zonal_stats(gdf, predict_path, stats=["mean"], nodata=-9999)
                        if stat['mean'] is not None
                    ])

                    mean_probhigh = np.mean([
                        stat['mean'] for stat in rasterstats.zonal_stats(gdf, probhigh_path, stats=["mean"], nodata=-9999)
                        if stat['mean'] is not None
                    ])

                    
                    # Store results
                    results.append({
                        "date": date_folder,
                        "iteration": iter_folder,
                        "treatment_type": treatment_type,
                        "vector_layer": layer,
                        "mean_predict_lmh": mean_predict,
                        "mean_prob_high": mean_probhigh
                    })
    
    return results

# %% [markdown]
# "C:\Users\bsf31\Documents\data\NL050\30m LUCAS LULC\30m LUCAS LULC\Untreated"

# %%
Untreated_results = process_rasters(Untreated_dir, "Untreated")

# %%
treated_prob_results = process_rasters(treated_cond_prob_dir, "treated")

# %%
Untreated_results
# Out:
# [{'date': '2020-01-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9715275063397719),
#   'mean_prob_high': np.float64(0.07441096098417611)},
#  {'date': '2020-01-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9804047749401511),
#   'mean_prob_high': np.float64(0.08852295698738631)},
#  {'date': '2020-01-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9742274240350857),
#   'mean_prob_high': np.float64(0.08026291425114288)},
#  {'date': '2020-01-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9698113810233918),
#   'mean_prob_high': np.float64(0.03965518567192841)},
#  {'date': '2020-01-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9716774873333289),
#   'mean_prob_high': np.float64(0.08372326514541474)},
#  {'date': '2020-01-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9804997286213524),
#   'mean_prob_high': np.float64(0.09996479709868861)},
#  {'date': '2020-01-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9743693197831249),
#   'mean_prob_high': np.float64(0.0884992412425858)},
#  {'date': '2020-01-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9698374566412618),
#   'mean_prob_high': np.float64(0.042657021934952924)},
#  {'date': '2020-02-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9718202801140916),
#   'mean_prob_high': np.float64(0.08244494525919126)},
#  {'date': '2020-02-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9806331711364611),
#   'mean_prob_high': np.float64(0.10177319775854757)},
#  {'date': '2020-02-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9744874355679353),
#   'mean_prob_high': np.float64(0.08246478231388893)},
#  {'date': '2020-02-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.97013992813198),
#   'mean_prob_high': np.float64(0.04194324633946184)},
#  {'date': '2020-02-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9718294962483113),
#   'mean_prob_high': np.float64(0.0950261445632312)},
#  {'date': '2020-02-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9806383986314532),
#   'mean_prob_high': np.float64(0.11697365744000271)},
#  {'date': '2020-02-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.97450002490701),
#   'mean_prob_high': np.float64(0.09471668387774551)},
#  {'date': '2020-02-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9702160281944934),
#   'mean_prob_high': np.float64(0.04914629071264749)},
#  {'date': '2020-03-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9717534377884007),
#   'mean_prob_high': np.float64(0.07722338101413156)},
#  {'date': '2020-03-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9806053846313696),
#   'mean_prob_high': np.float64(0.09500677683324586)},
#  {'date': '2020-03-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.974414489396841),
#   'mean_prob_high': np.float64(0.07823759051492171)},
#  {'date': '2020-03-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9701012121828168),
#   'mean_prob_high': np.float64(0.041777774641447496)},
#  {'date': '2020-03-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9707131564258368),
#   'mean_prob_high': np.float64(0.06734072580079581)},
#  {'date': '2020-03-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9797681481347815),
#   'mean_prob_high': np.float64(0.08067520642162933)},
#  {'date': '2020-03-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9735043667610033),
#   'mean_prob_high': np.float64(0.07368847501728017)},
#  {'date': '2020-03-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9688081578294323),
#   'mean_prob_high': np.float64(0.036958490510880196)},
#  {'date': '2020-04-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9708700866119758),
#   'mean_prob_high': np.float64(0.07363408564559858)},
#  {'date': '2020-04-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9798798893376194),
#   'mean_prob_high': np.float64(0.08924397532353283)},
#  {'date': '2020-04-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9736730286117751),
#   'mean_prob_high': np.float64(0.07797839400802802)},
#  {'date': '2020-04-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9691275386608122),
#   'mean_prob_high': np.float64(0.0385098633490915)},
#  {'date': '2020-04-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9713983663946492),
#   'mean_prob_high': np.float64(0.10280918494749887)},
#  {'date': '2020-04-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9804021586197246),
#   'mean_prob_high': np.float64(0.12581350511201983)},
#  {'date': '2020-04-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9741036087039151),
#   'mean_prob_high': np.float64(0.10428466425202088)},
#  {'date': '2020-04-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9698591857984682),
#   'mean_prob_high': np.float64(0.04811351725224173)},
#  {'date': '2020-05-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9718269967812834),
#   'mean_prob_high': np.float64(0.10908091502565842)},
#  {'date': '2020-05-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9806410836604917),
#   'mean_prob_high': np.float64(0.13345799232975109)},
#  {'date': '2020-05-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.974503629690723),
#   'mean_prob_high': np.float64(0.10938815941364682)},
#  {'date': '2020-05-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9702343718144415),
#   'mean_prob_high': np.float64(0.051107480494076235)},
#  {'date': '2020-05-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9718355919731572),
#   'mean_prob_high': np.float64(0.10641551884750204)},
#  {'date': '2020-05-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9806412570947083),
#   'mean_prob_high': np.float64(0.13285973581136412)},
#  {'date': '2020-05-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9745267167897559),
#   'mean_prob_high': np.float64(0.10306415910469881)},
#  {'date': '2020-05-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9702773075513623),
#   'mean_prob_high': np.float64(0.05129470081185908)},
#  {'date': '2020-06-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9718014998880043),
#   'mean_prob_high': np.float64(0.11410507263396115)},
#  {'date': '2020-06-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9805880338859901),
#   'mean_prob_high': np.float64(0.1418471404953709)},
#  {'date': '2020-06-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.974518607513113),
#   'mean_prob_high': np.float64(0.11020056823182292)},
#  {'date': '2020-06-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9703300821615664),
#   'mean_prob_high': np.float64(0.05389571608004316)},
#  {'date': '2020-06-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9717709471021263),
#   'mean_prob_high': np.float64(0.11053121054975633)},
#  {'date': '2020-06-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9805332580316859),
#   'mean_prob_high': np.float64(0.1413563955617865)},
#  {'date': '2020-06-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9745098132866529),
#   'mean_prob_high': np.float64(0.10076628674360445)},
#  {'date': '2020-06-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9703326349838237),
#   'mean_prob_high': np.float64(0.0523256286995845)},
#  {'date': '2020-07-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9717583688723358),
#   'mean_prob_high': np.float64(0.11675909511011774)},
#  {'date': '2020-07-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9804924050591595),
#   'mean_prob_high': np.float64(0.1467351386784263)},
#  {'date': '2020-07-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9745058238084038),
#   'mean_prob_high': np.float64(0.11112788668799745)},
#  {'date': '2020-07-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9703311955540861),
#   'mean_prob_high': np.float64(0.0538074204675542)},
#  {'date': '2020-07-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9717462526307106),
#   'mean_prob_high': np.float64(0.11494000886481211)},
#  {'date': '2020-07-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9804827176660708),
#   'mean_prob_high': np.float64(0.14388657359128587)},
#  {'date': '2020-07-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9744958613011557),
#   'mean_prob_high': np.float64(0.11062459449738382)},
#  {'date': '2020-07-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9703322653986362),
#   'mean_prob_high': np.float64(0.05100742282582284)},
#  {'date': '2020-08-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9717385117771865),
#   'mean_prob_high': np.float64(0.11986276683808361)},
#  {'date': '2020-08-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9804824601802339),
#   'mean_prob_high': np.float64(0.1494395085392365)},
#  {'date': '2020-08-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9744821165940393),
#   'mean_prob_high': np.float64(0.1158443714124562)},
#  {'date': '2020-08-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9703322380690975),
#   'mean_prob_high': np.float64(0.055290522032694536)},
#  {'date': '2020-08-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9716862863134285),
#   'mean_prob_high': np.float64(0.12488930186514542)},
#  {'date': '2020-08-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9803975691590177),
#   'mean_prob_high': np.float64(0.1571340786855087)},
#  {'date': '2020-08-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9744681775904567),
#   'mean_prob_high': np.float64(0.1197409494542515)},
#  {'date': '2020-08-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9703317777582665),
#   'mean_prob_high': np.float64(0.05933347156509081)},
#  {'date': '2020-09-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.971660117908652),
#   'mean_prob_high': np.float64(0.12852230207019413)},
#  {'date': '2020-09-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9803698477922894),
#   'mean_prob_high': np.float64(0.1616192488304321)},
#  {'date': '2020-09-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9744506862527209),
#   'mean_prob_high': np.float64(0.1218485960757095)},
#  {'date': '2020-09-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9703289549786087),
#   'mean_prob_high': np.float64(0.06137470962825038)},
#  {'date': '2020-09-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9716299698673977),
#   'mean_prob_high': np.float64(0.13333605554389202)},
#  {'date': '2020-09-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9803327926009883),
#   'mean_prob_high': np.float64(0.16873910252052485)},
#  {'date': '2020-09-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9744302445674076),
#   'mean_prob_high': np.float64(0.12381982209287903)},
#  {'date': '2020-09-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.970323470613883),
#   'mean_prob_high': np.float64(0.06157489573569422)},
#  {'date': '2020-10-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9715807108611799),
#   'mean_prob_high': np.float64(0.13948314059070752)},
#  {'date': '2020-10-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9802829691127226),
#   'mean_prob_high': np.float64(0.17764563669633338)},
#  {'date': '2020-10-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9744030184285926),
#   'mean_prob_high': np.float64(0.12823332705305665)},
#  {'date': '2020-10-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9702841187212216),
#   'mean_prob_high': np.float64(0.06687919626440625)},
#  {'date': '2020-10-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9716653266494176),
#   'mean_prob_high': np.float64(0.12688650212221897)},
#  {'date': '2020-10-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9803449558996875),
#   'mean_prob_high': np.float64(0.16296252370698067)},
#  {'date': '2020-10-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9744821486166637),
#   'mean_prob_high': np.float64(0.11366534549724992)},
#  {'date': '2020-10-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9702916046846823),
#   'mean_prob_high': np.float64(0.06000386658618065)},
#  {'date': '2020-11-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9717959235647764),
#   'mean_prob_high': np.float64(0.10506023929036847)},
#  {'date': '2020-11-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.980561054471233),
#   'mean_prob_high': np.float64(0.1307913152704211)},
#  {'date': '2020-11-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9745081650328143),
#   'mean_prob_high': np.float64(0.1019289534647185)},
#  {'date': '2020-11-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9703302108568962),
#   'mean_prob_high': np.float64(0.05275802216308511)},
#  {'date': '2020-11-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9718306849852795),
#   'mean_prob_high': np.float64(0.09611025805978374)},
#  {'date': '2020-11-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9806262131913567),
#   'mean_prob_high': np.float64(0.11907909795586638)},
#  {'date': '2020-11-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9745140261126635),
#   'mean_prob_high': np.float64(0.09584751200890733)},
#  {'date': '2020-11-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.970271701152321),
#   'mean_prob_high': np.float64(0.04865584006747451)},
#  {'date': '2020-12-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9718322377212788),
#   'mean_prob_high': np.float64(0.09287884561720429)},
#  {'date': '2020-12-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9806257080571368),
#   'mean_prob_high': np.float64(0.11473393923985065)},
#  {'date': '2020-12-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9745204538581461),
#   'mean_prob_high': np.float64(0.0925167856112791)},
#  {'date': '2020-12-01',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9702954007415967),
#   'mean_prob_high': np.float64(0.046873486534275755)},
#  {'date': '2020-12-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'sb_frontcountry_existing_trts_calmapper_epsg6350',
#   'mean_predict_lmh': np.float64(0.9718435907857682),
#   'mean_prob_high': np.float64(0.08387451819939074)},
#  {'date': '2020-12-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g3_northsbco_vmp_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9806488272499604),
#   'mean_prob_high': np.float64(0.10158821657485652)},
#  {'date': '2020-12-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350',
#   'mean_predict_lmh': np.float64(0.9745196415821574),
#   'mean_prob_high': np.float64(0.08710662636763254)},
#  {'date': '2020-12-16',
#   'iteration': 'Iteration_00',
#   'treatment_type': 'Untreated',
#   'vector_layer': 'g1_lompoc_rxfire_epsg6350',
#   'mean_predict_lmh': np.float64(0.9702053954668813),
#   'mean_prob_high': np.float64(0.0429425366719873)}]

# %%
df = pd.DataFrame(Untreated_results + treated_prob_results)
print(df.head())
# Out:
#          date     iteration treatment_type  \
# 0  2020-01-01  Iteration_00      Untreated
# 1  2020-01-01  Iteration_00      Untreated
# 2  2020-01-01  Iteration_00      Untreated
# 3  2020-01-01  Iteration_00      Untreated
# 4  2020-01-16  Iteration_00      Untreated
#
#                                        vector_layer  mean_predict_lmh  \
# 0  sb_frontcountry_existing_trts_calmapper_epsg6350          0.971528
# 1                  g3_northsbco_vmp_rxfire_epsg6350          0.980405
# 2     g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350          0.974227
# 3                         g1_lompoc_rxfire_epsg6350          0.969811
# 4  sb_frontcountry_existing_trts_calmapper_epsg6350          0.971677
#
#    mean_prob_high
# 0        0.074411
# 1        0.088523
# 2        0.080263
# 3        0.039655
# 4        0.083723

# %%
df
# Out:
#            date     iteration treatment_type  \
# 0    2020-01-01  Iteration_00      Untreated
# 1    2020-01-01  Iteration_00      Untreated
# 2    2020-01-01  Iteration_00      Untreated
# 3    2020-01-01  Iteration_00      Untreated
# 4    2020-01-16  Iteration_00      Untreated
# ..          ...           ...            ...
# 187  2020-12-01  Iteration_00        treated
# 188  2020-12-16  Iteration_00        treated
# 189  2020-12-16  Iteration_00        treated
# 190  2020-12-16  Iteration_00        treated
# 191  2020-12-16  Iteration_00        treated
#
#                                          vector_layer  mean_predict_lmh  \
# 0    sb_frontcountry_existing_trts_calmapper_epsg6350          0.971528
# 1                    g3_northsbco_vmp_rxfire_epsg6350          0.980405
# 2       g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350          0.974227
# 3                           g1_lompoc_rxfire_epsg6350          0.969811
# 4    sb_frontcountry_existing_trts_calmapper_epsg6350          0.971677
# ..                                                ...               ...
# 187                         g1_lompoc_rxfire_epsg6350          0.967214
# 188  sb_frontcountry_existing_trts_calmapper_epsg6350          0.970775
# 189                  g3_northsbco_vmp_rxfire_epsg6350          0.978608
# 190     g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350          0.972529
# 191                         g1_lompoc_rxfire_epsg6350          0.967114
#
#      mean_prob_high
# 0          0.074411
# 1          0.088523
# 2          0.080263
# 3          0.039655
# 4          0.083723
# ..              ...
# 187        0.045686
# 188        0.079984
# 189        0.094139
# 190        0.082496
# 191        0.041852
#
# [192 rows x 6 columns]

# %%
df["date"] = pd.to_datetime(df["date"])

# Set style for seaborn
sns.set_theme(style="whitegrid")

# Line plot: Trends over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x="date", y="mean_predict_lmh", hue="treatment_type", errorbar=None)
plt.title("Mean Predict LMH Over Time by Treatment Type")
plt.xticks(rotation=45)
plt.show()

# Boxplot: Distribution of mean_prob_high by treatment type
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="treatment_type", y="mean_prob_high")
plt.title("Distribution of Mean Probability High by Treatment Type")
plt.show()

# Barplot: Mean values by vector layer
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x="vector_layer", y="mean_predict_lmh", hue="treatment_type")
plt.xticks(rotation=90)
plt.title("Mean Predict LMH by Vector Layer and Treatment Type")
plt.show()

# %%
# Set the style
sns.set_style("whitegrid")

# Define the figure size
fig, ax = plt.subplots(figsize=(12, 6))

# Lineplot of mean_predict_lmh by vector_layer
sns.lineplot(data=df, x="date", y="mean_predict_lmh", hue="vector_layer", ax=ax, marker='o', errorbar=None)


# Set titles and labels
ax.set_title("Mean Predict LMH Over Time by Vector Layer")
ax.set_ylabel("Mean Predict LMH")
ax.set_xlabel("Date")

# Rotate x-axis labels for readability
plt.xticks(rotation=45)

# Move legend outside 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'
#legend = ax.legend(title="Vector Layer", bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
#legend = ax.legend(title="Vector Layer", bbox_to_anchor=(0.5, -0.15), loc='upper center', ncol=3, frameon=False)
legend = ax.legend(title="Vector Layer", bbox_to_anchor=(0.5, 1.15), loc='lower center', ncol=3, frameon=True)
# Adjust layout to make space for the legend
plt.tight_layout()
plt.subplots_adjust(top=0.85)  # Add extra space at the top

#plt.subplots_adjust(right=0.75) 
# Show the plot
plt.show()

# %%
# Set the style
sns.set_style("whitegrid")

# Filter dataset for only the selected vector layer
filtered_df = df[df["vector_layer"] == "sb_frontcountry_existing_trts_calmapper_epsg6350"]

# Define the figure size
fig, ax = plt.subplots(figsize=(12, 6))

# Lineplot for the selected vector layer (without confidence intervals)
sns.lineplot(data=filtered_df, x="date", y="mean_predict_lmh", ax=ax, marker='o', color='blue', label="sb_frontcountry_existing_trts_calmapper_epsg6350", errorbar=None)


# Set titles and labels
ax.set_title("Mean Predict LMH Over Time - sb_frontcountry_existing_trts_calmapper_epsg6350")
ax.set_ylabel("Mean Predict LMH")
ax.set_xlabel("Date")

# Rotate x-axis labels for readability
plt.xticks(rotation=45)

# Move legend inside the plot
ax.legend(title="Vector Layer", loc='lower right')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Set the style
sns.set_style("whitegrid")

# Filter dataset for only the selected vector layer
filtered_df = df[df["vector_layer"] == "g3_northsbco_vmp_rxfire_epsg6350"]

# Define the figure size
fig, ax = plt.subplots(figsize=(12, 6))

# Lineplot for the selected vector layer (without confidence intervals)
sns.lineplot(data=filtered_df, x="date", y="mean_predict_lmh", ax=ax, marker='o', color='orange', label="g3_northsbco_vmp_rxfire_epsg6350", errorbar=None)



# Set titles and labels
ax.set_title("Mean Predict LMH Over Time - g3_northsbco_vmp_rxfire_epsg6350")
ax.set_ylabel("Mean Predict LMH")
ax.set_xlabel("Date")

# Rotate x-axis labels for readability
plt.xticks(rotation=45)

# Move legend inside the plot
ax.legend(title="Vector Layer", loc='lower right')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Set the theme
sns.set_theme(style="ticks")

# Filter dataset for the four selected vector layers
selected_layers = [
    "sb_frontcountry_existing_trts_calmapper_epsg6350",
    "g3_northsbco_vmp_rxfire_epsg6350",
    "g2_usfsgaviota_300m_buffer_rxgrazing_epsg6350",
    "g1_lompoc_rxfire_epsg6350"
]

filtered_df = df[df["vector_layer"].isin(selected_layers)]

# Initialize a FacetGrid with larger size and better aspect ratio
grid = sns.FacetGrid(filtered_df, col="vector_layer", palette="tab10",
                     col_wrap=2, height=4, aspect=1.5, sharey=True)

# Plot only scatter points (no lines)
grid.map(sns.lineplot, "date", "mean_predict_lmh", errorbar=None)

# Adjust x-axis ticks for readability
grid.set_xticklabels(rotation=45)

# Set labels
grid.set_axis_labels("Date", "Mean Predict LMH")
grid.set_titles(col_template="{col_name}")  # Display vector layer name in each subplot

# Adjust layout for better spacing
grid.fig.subplots_adjust(wspace=0.3, hspace=0.5)  # Add space between plots

# Show the plots
plt.show()

# %%
# Set the style
sns.set_style("whitegrid")

# Define the figure size
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# Lineplot of mean_predict_lmh by vector_layer
sns.lineplot(data=df, x="date", y="mean_predict_lmh", hue="vector_layer", ax=axes[0], errorbar= None, marker='o', legend=False)
axes[0].set_title("Mean Predict LMH Over Time by Vector Layer")
axes[0].set_ylabel("Mean Predict LMH")




# Lineplot of mean_prob_high by vector_layer
sns.lineplot(data=df, x="date", y="mean_prob_high", hue="vector_layer", ax=axes[1], marker='o', errorbar=None)
axes[1].set_title("Mean Probability of High Over Time by Vector Layer")
axes[1].set_ylabel("Mean Probability High")
axes[1].set_xlabel("Date")



# Rotate x-axis labels for readability
plt.xticks(rotation=45)

legend = ax.legend(title="Vector Layer", bbox_to_anchor=(0.5, 1.15), loc='lower center', ncol=3, frameon=True)

plt.tight_layout()
plt.subplots_adjust(top=0.85) 
# Show the plots
plt.show()
